# %%
# %load_ext sql

# %%
from time import time
import configparser

# %%
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))
KEY=config.get('AWS','key')
SECRET= config.get('AWS','secret')

DWH_DB= config.get("DWH","DWH_DB")
DWH_DB_USER= config.get("DWH","DWH_DB_USER")
DWH_DB_PASSWORD= config.get("DWH","DWH_DB_PASSWORD")
DWH_PORT = config.get("DWH","DWH_PORT")
DWH_ENDPOINT = config.get("CLUSTER","HOST")
DWH_ROLE_ARN = config.get("IAM_ROLE","ARN")

# %%
import os 
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
# print(conn_string)
# %sql $conn_string
# Out:
# 'Connected: dwhuser@dwh'

# %%
# %%sql
# select * from stg_song_Data limit 10;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cdjih9ked3jt.us-east-1.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [(1, 'AR1C2IX1187B99BF74', None, None, '', 'Broken Spindles', 'SODZYPO12A8C13A91E', 'Burn My Body (Album Version)', 177.99791, 0),
#  (1, 'ARKULHT11C8A415E71', None, None, '', 'Jam Hsiao', 'SOYOWPX12AB018B46C', 'Green Door', 198.19057, 2009),
#  (1, 'AR06EB01187FB40150', None, None, 'Berkeley, CA', 'NOFX', 'SOPIKEG12A58291636', 'Stickin In My Eye', 144.50893, 1992),
#  (1, 'ARRQHXY11F4C83E430', None, None, '', 'Raheem Jamal', 'SOHKWBB12AB01874A3', 'Goodvibe', 221.1522, 0),
#  (1, 'AR2DUAO1187B99DDA4', None, None, '', 'FC Kahuna', 'SOENQZW12AB017CB92', 'Growler', 422.13832, 2002),
#  (1, 'AR6OL631187FB49241', None, None, 'California - LA', "Colby O'Donis", 'SOGSCWO12AB0182A60', 'Tell Me This', 233.35138, 2008),
#  (1, 'ARC6UC81187B989062', 40.71455, -74.00712, 'NY - New York City', 'Hem', 'SOIKIJC12AC3DFB3D2', 'Have Yourself A Merry Little Christmas', 133.27628, 2005),
# ...

# %%
# %%sql
# select * from stg_event_Data limit 10;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cdjih9ked3jt.us-east-1.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [('N.E.R.D. FEATURING MALICE', 'Logged In', 'Jayden', 'M', 0, 'Fox', 288.9922, 'free', 'New Orleans-Metairie, LA', 'PUT', 'NextSong', 1541033612796, 184, 'Am I High (Feat. Malice)', 200, datetime.datetime(2018, 11, 2, 1, 25, 34, 796000), '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', 101),
#  (None, 'Logged In', 'Stefany', 'F', 0, 'White', None, 'free', 'Lubbock, TX', 'GET', 'Home', 1540708070796, 82, None, 200, datetime.datetime(2018, 11, 2, 1, 29, 36, 796000), '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', 83),
# ...

# %%
# %%sql
# select * from stl_load_errors order by starttime desc
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cdjih9ked3jt.us-east-1.redshift.amazonaws.com:5439/dwh
# 17 rows affected.
# ...

# %%
# %%sql
# select * from fact_songplays limit 10;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cdjih9ked3jt.us-east-1.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [(245, datetime.datetime(2018, 11, 4, 19, 35, 15, 796000), 73, 'paid', 'SOULTKQ12AB018A183', 'ARKQQZA12086C116FC', 72, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (297, datetime.datetime(2018, 11, 5, 1, 48, 0, 796000), 44, 'paid', 'SOOXLKF12A6D4F594A', 'ARF5M7Q1187FB501E8', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (487, datetime.datetime(2018, 11, 5, 2, 9, 47, 796000), 44, 'paid', 'SOUNZHU12A8AE47481', 'AR37SX11187FB3E164', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
# ...

# %%
# %%sql
# select * from dim_users limit 10;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cdjih9ked3jt.us-east-1.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [(2, 'Jizelle', 'Benjamin', 'F', 'free'),
#  (4, 'Alivia', 'Terrell', 'F', 'free'),
#  (5, 'Elijah', 'Davis', 'M', 'free'),
#  (6, 'Cecilia', 'Owens', 'F', 'free'),
#  (6, 'Cecilia', 'Owens', 'F', 'free'),
#  (6, 'Cecilia', 'Owens', 'F', 'free'),
#  (6, 'Cecilia', 'Owens', 'F', 'free'),
#  (6, 'Cecilia', 'Owens', 'F', 'free'),
#  (6, 'Cecilia', 'Owens', 'F', 'free'),
#  (7, 'Adelyn', 'Jordan', 'F', 'free')]

# %%
# %%sql
# select * from dim_songs limit 10;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cdjih9ked3jt.us-east-1.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [('SOAAEHR12A6D4FB060', 'Slaves & Bulldozers', 'AR5N8VN1187FB37A4E', 1991, 415.81669),
#  ('SOAAOLZ12A6D4FB403', 'Somebody Knew', 'ARRSUF71187FB52F33', 1997, 188.08118),
#  ('SOAASSD12AB0181AA6', 'Song From Moulin Rouge', 'ARKXLIJ1187B9A4C54', 0, 195.02975),
#  ('SOAAUGN12AB01830B6', "Don't Wanna Suffer (Carbon Copy)", 'ARVC9W21187B99354B', 2003, 180.63628),
#  ('SOAAVXG12A6D4F7777', 'Best Song In The World', 'ARO4ZPQ1187FB5083E', 1996, 164.88444),
#  ('SOAAXYX12A8C133B77', 'Can I Get With You', 'AR4OH581187B9B7157', 2000, 242.72934),
#  ('SOABFQI12A58A7D162', 'Another World (Album Version)', 'AR9B5JX1187FB55D84', 1977, 494.10567),
#  ('SOABHYQ12A8C13D8FF', 'Inner Frame', 'ARAYDD71187FB5B775', 0, 247.43138),
#  ('SOABNPC12A8C13A9CC', 'Après Le Show', 'ARFM1EQ1187FB533ED', 2005, 223.4771),
# ...

# %%
# %%sql
# select * from dim_artists limit 10;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cdjih9ked3jt.us-east-1.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [('AR00FVC1187FB5BE3E', 'Panda', 'Monterrey, NL, México', 25.67084, -100.30953),
#  ('AR00TGQ1187B994F29', 'Paula Toller', '', 0.0, 0.0),
#  ('AR01G6G1187B9892EF', 'Tonino Carotone', '', 0.0, 0.0),
#  ('AR01SCU1187B9A693C', 'Street Dogs', 'Boston, MA', 0.0, 0.0),
#  ('AR026PU1187FB43FD9', 'The Vapors', '', 0.0, 0.0),
#  ('AR02YGA1187B9B8AC4', 'Bersuit Vergarabat', 'Buenos Aires', -34.60852, -58.37354),
#  ('AR02YGA1187B9B8AC4', 'Bersuit Vergarabat', 'Buenos Aires', -34.60852, -58.37354),
#  ('AR035N21187FB3938E', 'BT', 'Earth', 34.23294, -102.4102),
#  ('AR039B11187B9B30D0', 'John Williams', 'NEW YORK, New York', 0.0, 0.0),
#  ('AR03BDP1187FB5B324', 'Britney Spears', 'Kentwood, LA; Los Angeles, CA', 34.05349, -118.24532)]

# %%
# %%sql
# select * from dim_time limit 10;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cdjih9ked3jt.us-east-1.redshift.amazonaws.com:5439/dwh
# 10 rows affected.
# [(datetime.datetime(2018, 11, 1, 21, 24, 53, 796000), 21, 1, 44, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 1, 21, 55, 25, 796000), 21, 1, 44, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 2, 9, 4, 16, 796000), 9, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 9, 35, 25, 796000), 9, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 9, 42, 23, 796000), 9, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 9, 50, 23, 796000), 9, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 10, 19, 18, 796000), 10, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 10, 59, 19, 796000), 10, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 11, 13, 13, 796000), 11, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 2, 11, 29, 36, 796000), 11, 2, 44, 11, 2018, 5)]

# %%
# %%sql
# SELECT * FROM fact_songplays where artist_id is not null LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cdjih9ked3jt.us-east-1.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [(321, datetime.datetime(2018, 11, 3, 19, 33, 39, 796000), 95, 'paid', 'SOYTFSY12A6D4FD84E', 'ARRFSMX1187FB39B03', 152, 'Winston-Salem, NC', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"'),
#  (33, datetime.datetime(2018, 11, 3, 21, 14, 28, 796000), 49, 'free', 'SOFVOQL12A6D4F7456', 'ARPN0Y61187B9ABAA0', 195, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (21, datetime.datetime(2018, 11, 5, 10, 41, 2, 796000), 42, 'paid', 'SOCNCGL127D9786D66', 'AREHK7O1187B9ADDD7', 129, 'New York-Newark-Jersey City, NY-NJ-PA', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
# ...
